# %%
from nuts_ilp_model import MCMCConfig, GibbsConfig, DiagnosticConfig, run_experiment
import numpy as np

# %%
list_n = [1000]
list_d = [2, 5, 10, 20, 50, 100, 200, 500]
list_p = [5]
list_m = [1, 2, 5, 10, 20, 50, 100]

out_dir = "/Users/zhengyu/Desktop/UF/Research/Intergral_Linear_Programming/Constraints/Results/Simulation_NUTSMarginal"
mcmc_config = MCMCConfig(num_warmup=2000, num_samples=8000, num_chains=1, target_accept_prob=0.75)
diagnostic_config = DiagnosticConfig(max_plots=8, max_lag=50)
alg = "marginal_joint_green"
for n in list_n:
    for d in list_d:
        for p in list_p:
            for m in list_m:
                if m < d:
                    try:
                        mcmc, samples, diagnostics = run_experiment(
                            algorithm=alg,
                            n=n, p=p, d=d, m=m,
                            tau_beta=1.0,
                            mcmc_config=mcmc_config,
                            diagnostic_config=diagnostic_config,
                            data_seed=123,
                            mcmc_seed=456,
                            use_simulated_data=True,
                            save_results=True,
                            run_diagnostics=True,
                            output_dir=out_dir,
                        )
                        print(f"\n✓ {alg.upper()} completed successfully\n")
                    except Exception as e:
                        print(f"\n✗ {alg.upper()} failed: {e}\n")
                        import traceback
                        traceback.print_exc()
# Out:
# ...
# EXPERIMENT: MARGINAL_JOINT_GREEN
# Dimensions: n=1000, p=5, d=2, m=1
# tau_beta=1.0, data_seed=123, mcmc_seed=456
# Run stub: marginal_joint_green_ptntl__n1000_p5_d2_m1__tau1.0__w2000_s8000_c1_ap0.75__ds123_ms456
# ...
#
# Generating simulation data...
# Data generated: y (1000, 2), X (1000, 5), A (1, 2), b (1,)
# Active constraint positions: L = 212
#
# Running marginal_joint_green algorithm...
# To turn off green mode, set MCMCConfig.green_mode=False
# ...
# sample: 100%|██████████| 1500/1500 [00:02<00:00, 610.19it/s, 15 steps of size 3.22e-01. acc. prob=0.82]
# MCMC completed in 0.33 minutes (19.8 seconds)
#
# Computing diagnostics...
#
# ...
# BETA DIAGNOSTICS SUMMARY
# ...
# RMSE: 0.1129
# 95% CI Coverage: 0.900
# ESS: min=11904.2, median=14770.0
# ...
#
# ...
# EFFICIENCY SUMMARY
# ...
# Runtime: 19.8 seconds (0.33 minutes)
# ESS/second (median): 746.47
# ESS/second (min): 601.63
# Seconds per ESS (median): 0.001
# ...
#
# ...

# %%
# Higher Dimension for NUTS

list_n = [1000]
list_d = [3000]
list_p = [5]
list_m = [100]

out_dir = "/Users/zhengyu/Desktop/UF/Research/Intergral_Linear_Programming/Constraints/Results/Simulation_NUTSMarginal"
mcmc_config = MCMCConfig(num_warmup=2000, num_samples=8000, num_chains=1, target_accept_prob=0.75)
diagnostic_config = DiagnosticConfig(max_plots=8, max_lag=50)
alg = "marginal_joint_green"
for n in list_n:
    for d in list_d:
        for p in list_p:
            for m in list_m:
                if m < d:
                    try:
                        mcmc, samples, diagnostics = run_experiment(
                            algorithm=alg,
                            n=n, p=p, d=d, m=m,
                            tau_beta=1.0,
                            mcmc_config=mcmc_config,
                            diagnostic_config=diagnostic_config,
                            data_seed=123,
                            mcmc_seed=456,
                            use_simulated_data=True,
                            save_results=True,
                            run_diagnostics=True,
                            output_dir=out_dir,
                        )
                        print(f"\n✓ {alg.upper()} completed successfully\n")
                    except Exception as e:
                        print(f"\n✗ {alg.upper()} failed: {e}\n")
                        import traceback
                        traceback.print_exc()
# Out:
# ...
# EXPERIMENT: MARGINAL_JOINT_GREEN
# Dimensions: n=1000, p=5, d=3000, m=100
# tau_beta=1.0, data_seed=123, mcmc_seed=456
# Run stub: marginal_joint_green_ptntl__n1000_p5_d3000_m100__tau1.0__w2000_s8000_c1_ap0.75__ds123_ms456
# ...
#
# Generating simulation data...
# Data generated: y (1000, 3000), X (1000, 5), A (100, 3000), b (100,)
# Active constraint positions: L = 51952
#
# Running marginal_joint_green algorithm...
# To turn off green mode, set MCMCConfig.green_mode=False
# ...
# sample: 100%|██████████| 1500/1500 [23:24<00:00,  1.07it/s, 63 steps of size 6.28e-02. acc. prob=0.81]
# MCMC completed in 264.82 minutes (15889.4 seconds)
#
# Computing diagnostics...
#
# ...
# BETA DIAGNOSTICS SUMMARY
# ...
# RMSE: 0.0979
# 95% CI Coverage: 0.921
# ESS: min=3046.0, median=9216.0
# ...
#
# ...
# EFFICIENCY SUMMARY
# ...
# Runtime: 15889.4 seconds (264.82 minutes)
# ESS/second (median): 0.58
# ESS/second (min): 0.19
# Seconds per ESS (median): 1.724
# ...
#
# ...

# %%
# Higher Dimension for NUTS

list_n = [1000]
list_d = [1000]
list_p = [5]
list_m = [1,5,10,20,50]

out_dir = "/Users/zhengyu/Desktop/UF/Research/Intergral_Linear_Programming/Constraints/Results/Simulation_NUTSMarginal"
mcmc_config = MCMCConfig(num_warmup=2000, num_samples=8000, num_chains=1, target_accept_prob=0.75)
diagnostic_config = DiagnosticConfig(max_plots=8, max_lag=50)
alg = "marginal_joint_green"
for n in list_n:
    for d in list_d:
        for p in list_p:
            for m in list_m:
                if m < d:
                    try:
                        mcmc, samples, diagnostics = run_experiment(
                            algorithm=alg,
                            n=n, p=p, d=d, m=m,
                            tau_beta=1.0,
                            mcmc_config=mcmc_config,
                            diagnostic_config=diagnostic_config,
                            data_seed=123,
                            mcmc_seed=456,
                            use_simulated_data=True,
                            save_results=True,
                            run_diagnostics=True,
                            output_dir=out_dir,
                        )
                        print(f"\n✓ {alg.upper()} completed successfully\n")
                    except Exception as e:
                        print(f"\n✗ {alg.upper()} failed: {e}\n")
                        import traceback
                        traceback.print_exc()
# Out:
# ...
# EXPERIMENT: MARGINAL_JOINT_GREEN
# Dimensions: n=1000, p=5, d=1000, m=1
# tau_beta=1.0, data_seed=123, mcmc_seed=456
# Run stub: marginal_joint_green_ptntl__n1000_p5_d1000_m1__tau1.0__w2000_s8000_c1_ap0.75__ds123_ms456
# ...
#
# Generating simulation data...
# Data generated: y (1000, 1000), X (1000, 5), A (1, 1000), b (1,)
# Active constraint positions: L = 733
#
# Running marginal_joint_green algorithm...
# To turn off green mode, set MCMCConfig.green_mode=False
# ...
# sample: 100%|██████████| 1500/1500 [02:48<00:00,  8.88it/s, 31 steps of size 1.44e-01. acc. prob=0.81]
# MCMC completed in 24.51 minutes (1470.9 seconds)
#
# Computing diagnostics...
#
# ...
# BETA DIAGNOSTICS SUMMARY
# ...
# RMSE: 0.0823
# 95% CI Coverage: 0.941
# ESS: min=4213.3, median=12034.6
# ...
#
# ...
# EFFICIENCY SUMMARY
# ...
# Runtime: 1470.9 seconds (24.51 minutes)
# ESS/second (median): 8.18
# ESS/second (min): 2.86
# Seconds per ESS (median): 0.122
# ...
#
# ...

# %%
# Higher Dimension for NUTS

list_n = [1000]
list_d = [2000, 3000]
list_p = [5]
list_m = [200]

out_dir = "/Users/zhengyu/Desktop/UF/Research/Intergral_Linear_Programming/Constraints/Results/Simulation_NUTSMarginal"
mcmc_config = MCMCConfig(num_warmup=2000, num_samples=8000, num_chains=1, target_accept_prob=0.75)
diagnostic_config = DiagnosticConfig(max_plots=8, max_lag=50)
alg = "marginal_joint_green"
for n in list_n:
    for d in list_d:
        for p in list_p:
            for m in list_m:
                if m < d:
                    try:
                        mcmc, samples, diagnostics = run_experiment(
                            algorithm=alg,
                            n=n, p=p, d=d, m=m,
                            tau_beta=1.0,
                            mcmc_config=mcmc_config,
                            diagnostic_config=diagnostic_config,
                            data_seed=123,
                            mcmc_seed=456,
                            use_simulated_data=True,
                            save_results=True,
                            run_diagnostics=True,
                            output_dir=out_dir,
                        )
                        print(f"\n✓ {alg.upper()} completed successfully\n")
                    except Exception as e:
                        print(f"\n✗ {alg.upper()} failed: {e}\n")
                        import traceback
                        traceback.print_exc()
# Out:
# ...
# EXPERIMENT: MARGINAL_JOINT_GREEN
# Dimensions: n=1000, p=5, d=2000, m=200
# tau_beta=1.0, data_seed=123, mcmc_seed=456
# Run stub: marginal_joint_green_ptntl__n1000_p5_d2000_m200__tau1.0__w2000_s8000_c1_ap0.75__ds123_ms456
# ...
#
# Generating simulation data...
# Data generated: y (1000, 2000), X (1000, 5), A (200, 2000), b (200,)
# Active constraint positions: L = 98603
#
# Running marginal_joint_green algorithm...
# To turn off green mode, set MCMCConfig.green_mode=False
# ...
# sample: 100%|██████████| 1500/1500 [40:00<00:00,  1.60s/it, 127 steps of size 4.29e-02. acc. prob=0.82]
# MCMC completed in 260.57 minutes (15634.1 seconds)
#
# Computing diagnostics...
#
# ...
# BETA DIAGNOSTICS SUMMARY
# ...
# RMSE: 0.1255
# 95% CI Coverage: 0.879
# ESS: min=5808.4, median=14857.6
# ...
#
# ...
# EFFICIENCY SUMMARY
# ...
# Runtime: 15634.1 seconds (260.57 minutes)
# ESS/second (median): 0.95
# ESS/second (min): 0.37
# Seconds per ESS (median): 1.052
# ...
#
# ...

# %%
# Higher Dimension for NUTS

list_n = [1000]
list_d = [3000]
list_p = [5]
list_m = [1,5,10,20,50]

out_dir = "/Users/zhengyu/Desktop/UF/Research/Intergral_Linear_Programming/Constraints/Results/Simulation_NUTSMarginal"
mcmc_config = MCMCConfig(num_warmup=2000, num_samples=8000, num_chains=1, target_accept_prob=0.75)
diagnostic_config = DiagnosticConfig(max_plots=8, max_lag=50)
alg = "marginal_joint_green"
for n in list_n:
    for d in list_d:
        for p in list_p:
            for m in list_m:
                if m < d:
                    try:
                        mcmc, samples, diagnostics = run_experiment(
                            algorithm=alg,
                            n=n, p=p, d=d, m=m,
                            tau_beta=1.0,
                            mcmc_config=mcmc_config,
                            diagnostic_config=diagnostic_config,
                            data_seed=123,
                            mcmc_seed=456,
                            use_simulated_data=True,
                            save_results=True,
                            run_diagnostics=True,
                            output_dir=out_dir,
                        )
                        print(f"\n✓ {alg.upper()} completed successfully\n")
                    except Exception as e:
                        print(f"\n✗ {alg.upper()} failed: {e}\n")
                        import traceback
                        traceback.print_exc()
# Out:
# ...
# EXPERIMENT: MARGINAL_JOINT_GREEN
# Dimensions: n=1000, p=5, d=3000, m=1
# tau_beta=1.0, data_seed=123, mcmc_seed=456
# Run stub: marginal_joint_green_ptntl__n1000_p5_d3000_m1__tau1.0__w2000_s8000_c1_ap0.75__ds123_ms456
# ...
#
# Generating simulation data...
# Data generated: y (1000, 3000), X (1000, 5), A (1, 3000), b (1,)
# Active constraint positions: L = 726
#
# Running marginal_joint_green algorithm...
# To turn off green mode, set MCMCConfig.green_mode=False
# ...
# sample: 100%|██████████| 1500/1500 [30:15<00:00,  1.21s/it, 127 steps of size 4.74e-02. acc. prob=0.84]
# MCMC completed in 183.08 minutes (10984.8 seconds)
#
# Computing diagnostics...
#
# ...
# BETA DIAGNOSTICS SUMMARY
# ...
# RMSE: 0.0801
# 95% CI Coverage: 0.947
# ESS: min=7129.5, median=14716.4
# ...
#
# ...
# EFFICIENCY SUMMARY
# ...
# Runtime: 10984.8 seconds (183.08 minutes)
# ESS/second (median): 1.34
# ESS/second (min): 0.65
# Seconds per ESS (median): 0.746
# ...
#
# ...

# %%
# Higher Dimension for NUTS

list_n = [1000]
list_d = [2000]
list_p = [5]
list_m = [1,5,10,20,50]

out_dir = "/Users/zhengyu/Desktop/UF/Research/Intergral_Linear_Programming/Constraints/Results/Simulation_NUTSMarginal"
mcmc_config = MCMCConfig(num_warmup=2000, num_samples=8000, num_chains=1, target_accept_prob=0.75)
diagnostic_config = DiagnosticConfig(max_plots=8, max_lag=50)
alg = "marginal_joint_green"
for n in list_n:
    for d in list_d:
        for p in list_p:
            for m in list_m:
                    try:
                        mcmc, samples, diagnostics = run_experiment(
                            algorithm=alg,
                            n=n, p=p, d=d, m=m,
                            tau_beta=1.0,
                            mcmc_config=mcmc_config,
                            diagnostic_config=diagnostic_config,
                            data_seed=123,
                            mcmc_seed=456,
                            use_simulated_data=True,
                            save_results=True,
                            run_diagnostics=True,
                            output_dir=out_dir,
                        )
                        print(f"\n✓ {alg.upper()} completed successfully\n")
                    except Exception as e:
                        print(f"\n✗ {alg.upper()} failed: {e}\n")
                        import traceback
                        traceback.print_exc()
# Out:
# ...
# EXPERIMENT: MARGINAL_JOINT_GREEN
# Dimensions: n=1000, p=5, d=2000, m=1
# tau_beta=1.0, data_seed=123, mcmc_seed=456
# Run stub: marginal_joint_green_ptntl__n1000_p5_d2000_m1__tau1.0__w2000_s8000_c1_ap0.75__ds123_ms456
# ...
#
# Generating simulation data...
# Data generated: y (1000, 2000), X (1000, 5), A (1, 2000), b (1,)
# Active constraint positions: L = 708
#
# Running marginal_joint_green algorithm...
# To turn off green mode, set MCMCConfig.green_mode=False
# ...
# sample: 100%|██████████| 1500/1500 [05:12<00:00,  4.79it/s, 31 steps of size 1.13e-01. acc. prob=0.81]
# MCMC completed in 41.64 minutes (2498.2 seconds)
#
# Computing diagnostics...
#
# ...
# BETA DIAGNOSTICS SUMMARY
# ...
# RMSE: 0.0804
# 95% CI Coverage: 0.945
# ESS: min=2244.6, median=7220.3
# ...
#
# ...
# EFFICIENCY SUMMARY
# ...
# Runtime: 2498.2 seconds (41.64 minutes)
# ESS/second (median): 2.89
# ESS/second (min): 0.90
# Seconds per ESS (median): 0.346
# ...
#
# ...
