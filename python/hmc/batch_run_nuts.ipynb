# %%
from nuts_ilp_model import MCMCConfig, DiagnosticConfig, run_experiment
import numpy as np

# %%
list_n = [1000]
list_d = [5, 10]
list_p = [5]
list_m = [1, 2, 5, 10, 20, 50, 100]

out_dir = "../../results/results/hmc"
mcmc_config = MCMCConfig(num_warmup=1000, num_samples=2000, num_chains=1, target_accept_prob=0.75) # Do not change num_chains
diagnostic_config = DiagnosticConfig(max_plots=8, max_lag=50)
alg = "marginal_joint_green"
for n in list_n:
    for d in list_d:
        for p in list_p:
            for m in list_m:
                if m < d:
                    try:
                        mcmc, samples, diagnostics = run_experiment(
                            algorithm=alg,
                            n=n, p=p, d=d, m=m,
                            tau_beta=1.0,
                            mcmc_config=mcmc_config,
                            diagnostic_config=diagnostic_config,
                            data_seed=123,
                            mcmc_seed=456,
                            use_simulated_data=True,
                            save_results=True,
                            run_diagnostics=True,
                            output_dir=out_dir,
                        )
                        print(f"\n✓ {alg.upper()} completed successfully\n")
                    except Exception as e:
                        print(f"\n✗ {alg.upper()} failed: {e}\n")
                        import traceback
                        traceback.print_exc()
# Out:
# ...
# EXPERIMENT: MARGINAL_JOINT_GREEN
# Dimensions: n=1000, p=5, d=5, m=1
# tau_beta=1.0, data_seed=123, mcmc_seed=456
# Run stub: marginal_joint_green_ptntl__n1000_p5_d5_m1__tau1.0__w100_s200_c1_ap0.75__ds123_ms456
# ...
#
# Generating simulation data...
# Data generated: y (1000, 5), X (1000, 5), A (1, 5), b (1,)
# Active constraint positions: L = 627
#
# Running marginal_joint_green algorithm...
# To turn off green mode, set MCMCConfig.green_mode=False
# sample: 100%|██████████| 600/600 [00:04<00:00, 140.91it/s, 15 steps of size 2.47e-01. acc. prob=0.85]
# MCMC completed in 0.11 minutes (6.8 seconds)
#
# Computing diagnostics...
#
# ...
# BETA DIAGNOSTICS SUMMARY
# ...
# RMSE: 0.2335
# 95% CI Coverage: 0.680
# ESS: min=88.6, median=222.6
# ...
#
# ...
# EFFICIENCY SUMMARY
# ...
# Runtime: 6.8 seconds (0.11 minutes)
# ESS/second (median): 32.96
# ESS/second (min): 13.13
# Seconds per ESS (median): 0.030
# ...
#
#
# ...
# MCMC HEALTH WARNINGS
# ...
# [ESS_MIN] Min ESS = 88.6 < 100. Very low effective sample size.
# ...
